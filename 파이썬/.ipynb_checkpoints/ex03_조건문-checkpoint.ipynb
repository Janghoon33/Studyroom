# %% [markdown]
# ###조건문
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# if문 구조
num1 = 19
num2 = 15

if num1>num2 :
    print('num1이 더 큽니다')
    print('실행문장2')
    if True : 
        print("2번째 조건문")
        
print('if문이 종료되었습니다.')
# Out:
# num1이 더 큽니다
# 실행문장2
# if문이 종료되었습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = int(input("첫번째 정수 입력 >> "))
num2 = int(input("두번째 정수 입력 >> "))
if num1>num2 : 
    print("첫번째 정수가 더 큽니다.")
elif num1==num2 : 
    print("두 수가 똑같습니다.")
else:
    print("두번째 정수가 더 큽니다.")
# Out:
# 첫번째 정수 입력 >> 7
# 두번째 정수 입력 >> 7
# 두 수가 똑같습니다.

# %%
# 변수 score에 점수를 입력받아 학점 부여하기
score = int(input("점수 입력 >> "))

if score>100:
    print('잘못된 점수입니다.')
elif score<=100 and score>=90 : 
    print(f'{score}점은 A학점입니다.')
elif score<90 and score>=80 : 
    print(f'{score}점은 B학점입니다.')
elif score<80 and score>=70 :
    print(f'{score}점은 C학점입니다.')
elif score<70 and score>=60 : 
    print(f'{score}점은 D학점입니다.')
else:
    print(f'{score}점은 F학점입니다.')
# Out:
# 점수 입력 >> 89
# 89점은 B학점입니다.

# %%
print('''
================================================
================---- 자판기 ----================
================================================
== 1.콜라 == 2.사이다 ==  3.물  =======insert===
==--------==----------==--------=======------===
==   600  ==    800   ==  1000  ======= O00원===
=======================================------===
================================================
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==+++++++++++++++     SMHRD    +++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
================================================
================================================
  ===                                      ===
  ===                                      ===
''')
num5 = int(input("insert coin >> "))
num6 = int(input("메뉴 선택 >> "))
a = (num5-600)//1000
b = (num5-600)%1000//500
c = (num5-600)%1000%500//100

d = (num5-800)//1000
e = (num5-800)%1000//500
f = (num5-800)%1000%500//100

h = (num5-1000)//1000
i = (num5-1000)%1000//500
j = (num5-1000)%1000%500//100

if num6==1 :
    print(f'잔돈 >> 1000원 {a}개, 500원 {b}개, 100원 {c}개')
elif num6==2 :
    print(f'잔돈 >> 1000원 {d}개, 500원 {e}개, 100원 {f}개')
elif num6==3 :
    print(f'잔돈 >> 1000원 {h}개, 500원 {i}개, 100원 {j}개')
elif num5<600 : 
    print("금액이 부족합니다.")
else :
    print("다시 실행하여주세요")
# Out:
# ...
# ================---- 자판기 ----================
# ...
# == 1.콜라 == 2.사이다 ==  3.물  =======insert===
# ==--------==----------==--------=======------===
# ==   600  ==    800   ==  1000  ======= O00원===
# =======================================------===
# ...
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==+++++++++++++++     SMHRD    +++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ...
#   ===                                      ===
#   ===                                      ===
#
# insert coin >> 3800
# 메뉴 선택 >> 3
# 잔돈 >> 1000원 2개, 500원 1개, 100원 3개
