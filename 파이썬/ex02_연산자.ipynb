# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = 10
num2 = 5

print(num1/num2)
print(num1//num2)
# Out:
# 2.0
# 2

# %%
# 문자열끼리의 산술 연산은 더하기만 가능하다.
str1 = "안녕"
str2= "하세요"
print(str1+str2)
# Out:
# 안녕하세요

# %%
str3 = "10"
str4 = 7
print(str3+str(str4))
print(int(str3)+str4)
# Out:
# 107
# 17

# %%
# 문자열과 숫자는 곱하기 연산은 가능하다.
num1 = 5
str5 = "*"
print(str5*num1)
# Out:
# *****

# %%
# 키보드로 입력받는 input() 사용법
num2 = int(input("정수를 입력하세요 >> "))
print(type(num2))
print(num2+1)
# Out:
# 정수를 입력하세요 >> 30
# <class 'int'>
# 31

# %%
num1 = int(input("정수를 입력하세요 >> "))
num2 = int(input("정수를 입력하세요 >> "))

print(f"더하기 결과 : {num1+num2}")
print(f"빼기 결과 : {num1-num2}")
print(f"곱하기기 결과 : {num1*num2}")
print(f"나누기 결과 : {num1/num2}")
# Out:
# 정수를 입력하세요 >> 3
# 정수를 입력하세요 >> 7
# 더하기 결과 : 10
# 빼기 결과 : -4
# 곱하기기 결과 : 21
# 나누기 결과 : 0.42857142857142855

# %%
# 반올림 함수
print(round(123.65868,3))

# 문자길이 확인
str6 = "안녕하세요"
print(len(str6))
# Out:
# 123.659
# 5

# %%
time = int(input("시간 입력 >> "))
hour = time//3600
minute = time%3600//60
second = time%60
print(f"{hour}시간 {minute}분 {second}초")
# Out:
# 시간 입력 >> 3723
# 1시간 2분 3초

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input("정수 입력 >> "))
power = int(input("지수 입력 >> "))
print(f"{num}의 {power}승은 {num**power}입니다")
# Out:
# 정수 입력 >> 2
# 지수 입력 >> 3
# 2의 3승은 8입니다

# %% [markdown]
# ### 대입연산자
# ![image.png](attachment:image.png)

# %%
# 치환 1 (일반적인 방법)
num1=10
num2=17

temp = num1
num1= num2
num2 = temp

print(num1,num2)
# Out:
# 17 10

# %%
# 치환 2(python에만 사용 가능한 방법)
num3 = 10
num4 = 15

num3, num4 = num4,num3

# %% [markdown]
# ### 비교 연산자
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 논리연산자
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 삼항연산자
# ![image.png](attachment:image.png)

# %%
score = 80
result = "합격"if score>=60 else "불합격"
print(result)
# Out:
# 합격

# %%
a = int(input("정수 입력 >> "))
b = int(input("정수 입력 >> "))
res = "a : "+str(a) if a>b else "b : "+str(b)
res2 = f'a : {a}' if a>b else f'b : {b}'
print(res2)
# Out:
# 정수 입력 >> 5
# 정수 입력 >> 9
# b : 9

# %%
c = int(input("정수 입력 >> "))
res3 = f'{c}는(은) 짝수입니다.' if c%2 == 0 else f'{c}는(은) 홀수입니다.'
print(res3)
# Out:
# 정수 입력 >> 33
# 33는(은) 홀수입니다.
